# %%
# import dependencies
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\skill\\Play-code\\hospital-operations-analysis\\RAW_DATA\\Hospital Operations(Sheet1).csv')

# %%
df.head()
# Out:
#   patient_id visit_id  age  gender admission_date discharge_date  \
# 0     P02256  V000001   58  Female     2025-05-29     2025-05-29
# 1     P03204  V000002   66    Male     2025-06-21     2025-06-24
# 2     P03007  V000003   90  Female     2024-09-20     2024-09-20
# 3     P00592  V000004   49    Male     2025-04-13     2025-04-19
# 4     P00572  V000005   22    Male     2024-02-21     2024-02-21
#
#          department diagnosis_category  visit_type doctor_id  \
# 0        Cardiology            Cardiac  Outpatient    DR0094
# 1  General Medicine             Gastro   Inpatient    DR0176
# 2         Emergency             Injury  Outpatient    DR0111
# 3               ICU            Cardiac   Inpatient    DR0184
# 4  General Medicine             Injury  Outpatient    DR0167
#
#    wait_time_minutes  treatment_cost insurance_type appointment_status  \
# 0                 39         2592.97     Government           Attended
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          10000 non-null  object
#  1   visit_id            10000 non-null  object
#  2   age                 10000 non-null  int64
#  3   gender              10000 non-null  object
#  4   admission_date      10000 non-null  datetime64[ns]
#  5   discharge_date      10000 non-null  datetime64[ns]
#  6   department          10000 non-null  object
#  7   diagnosis_category  10000 non-null  object
#  8   visit_type          10000 non-null  object
#  9   doctor_id           10000 non-null  object
#  10  wait_time_minutes   10000 non-null  int64
#  11  treatment_cost      10000 non-null  float64
#  12  insurance_type      10000 non-null  object
#  13  appointment_status  10000 non-null  object
#  14  readmitted_30_days  10000 non-null  object
# ...

# %%
df["admission_date"] = pd.to_datetime(df["admission_date"])
df["discharge_date"] = pd.to_datetime(df["discharge_date"])
df["length_of_stay"] = (df["discharge_date"] - df["admission_date"]).dt.days

# %%
df = df[df["length_of_stay"] >= 0]

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.columns
# Out:
# Index(['patient_id', 'visit_id', 'age', 'gender', 'admission_date',
#        'discharge_date', 'department', 'diagnosis_category', 'visit_type',
#        'doctor_id', 'wait_time_minutes', 'treatment_cost', 'insurance_type',
#        'appointment_status', 'readmitted_30_days', 'outcome_status',
#        'bed_assigned', 'city', 'admission_source', 'length_of_stay'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.isnull().sum()
# Out:
# patient_id            0
# visit_id              0
# age                   0
# gender                0
# admission_date        0
# discharge_date        0
# department            0
# diagnosis_category    0
# visit_type            0
# doctor_id             0
# wait_time_minutes     0
# treatment_cost        0
# insurance_type        0
# appointment_status    0
# readmitted_30_days    0
# outcome_status        0
# bed_assigned          0
# city                  0
# admission_source      0
# length_of_stay        0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
# !pip install mysql-connector-python sqlalchemy

# %%
import mysql.connector
from sqlalchemy import create_engine

try:
    db = mysql.connector.connect(
        host="localhost",
        username="root",
        password="password",
        database="healthcare_dep"
    )
    print("Connection successful!")
except mysql.connector.Error as err:
    print(f"Error: {err}")
# Out:
# Connection successful!

# %%
engine = create_engine('mysql+mysqlconnector://root:password@localhost/healthcare_dep')
    
    # Write DataFrame to MySQL
table_name = "hospital_data"
df.to_sql(table_name, con=engine, if_exists='replace', index=False)
# Out:
# 10000

# %%
# Read back sample
pd.read_sql("SELECT * FROM hospital_data LIMIT 10;", engine)
# Out:
#   patient_id visit_id  age  gender admission_date discharge_date  \
# 0     P02256  V000001   58  Female     2025-05-29     2025-05-29
# 1     P03204  V000002   66    Male     2025-06-21     2025-06-24
# 2     P03007  V000003   90  Female     2024-09-20     2024-09-20
# 3     P00592  V000004   49    Male     2025-04-13     2025-04-19
# 4     P00572  V000005   22    Male     2024-02-21     2024-02-21
# 5     P01078  V000006   39    Male     2025-12-09     2025-12-09
# 6     P01428  V000007   77    Male     2025-01-24     2025-01-24
# 7     P01618  V000008   86  Female     2024-06-03     2024-06-03
# 8     P02712  V000009   76  Female     2025-01-11     2025-01-26
# 9     P00242  V000010   75    Male     2024-08-01     2024-08-04
#
#          department diagnosis_category  visit_type doctor_id  \
# 0        Cardiology            Cardiac  Outpatient    DR0094
# 1  General Medicine             Gastro   Inpatient    DR0176
# 2         Emergency             Injury  Outpatient    DR0111
# ...
